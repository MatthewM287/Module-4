# %% [markdown]
# <a href="https://colab.research.google.com/github/MatthewM287/Module-4/blob/main/Module_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
packages_entered = int(input("How many pacakges have you purchased"))
if packages_entered == 10-19:
  print("Your discount is 10%")
if 20-49:
  print("your discount is 20%")
elif 50-99:
  print("Your discount is 30%")
elif packages_entered>=100:
  print("Your discount is 40%")
# Out:
# How many pacakges have you purchased50
# your discount is 20%

# %%
Weight_entered = int(input("how muuch does your package weigh"))
if Weight_entered<2:
  print("The rate is $1.50")
elif 2-6:
  print("The rate is $3.00")
elif Weight_entered>6-10:
  print("The rate is $4.00")
elif Weight_entered>10:
  print("The rate is $4.75")
